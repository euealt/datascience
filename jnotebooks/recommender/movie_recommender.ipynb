# %%
import pandas as pd
ratings_cols = ['user_id', 'movie_id', 'rating']
ratings = pd.read_csv(
    '../../datasets/movie_ratings.data',
    sep='\t', 
    names=ratings_cols, 
    usecols=range(3), 
    encoding="ISO-8859-1"
)
ratings.head()
# Out:
#    user_id  movie_id  rating
# 0        0        50       5
# 1        0       172       5
# 2        0       133       1
# 3      196       242       3
# 4      186       302       3

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100003 entries, 0 to 100002
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   user_id   100003 non-null  int64
#  1   movie_id  100003 non-null  int64
#  2   rating    100003 non-null  int64
# dtypes: int64(3)
# memory usage: 2.3 MB

# %%
ratings.groupby('user_id').size()
# Out:
# user_id
# 0        3
# 1      272
# 2       62
# 3       54
# 4       24
#       ...
# 939     49
# 940    107
# 941     22
# 942     79
# 943    168
# Length: 944, dtype: int64

# %%
movie_cols = ['movie_id', 'title']
movies = pd.read_csv(
    '../../datasets/movie_items.item', 
    sep='|', 
    usecols=range(2), 
    encoding="ISO-8859-1",
    names=movie_cols
)

movies.head()
# Out:
#    movie_id              title
# 0         1   Toy Story (1995)
# 1         2   GoldenEye (1995)
# 2         3  Four Rooms (1995)
# 3         4  Get Shorty (1995)
# 4         5     Copycat (1995)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1682 entries, 0 to 1681
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  1682 non-null   int64
#  1   title     1682 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 26.4+ KB

# %%
# Merge movies and ratings

movies_ratings = pd.merge(movies, ratings)
movies_ratings.head()
# Out:
#    movie_id             title  user_id  rating
# 0         1  Toy Story (1995)      308       4
# 1         1  Toy Story (1995)      287       5
# 2         1  Toy Story (1995)      148       4
# 3         1  Toy Story (1995)      280       4
# 4         1  Toy Story (1995)       66       3

# %%
# Build a matrix of users vs movies
movie_matrix = movies_ratings.pivot_table(index=['user_id'], columns=['title'], values='rating')
movie_matrix.head(10)
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
# 6                              NaN           NaN                    NaN
# 7                              NaN           NaN                    NaN
# 8                              NaN           NaN                    NaN
# 9                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# 5                        NaN         NaN                          NaN
# 6                        4.0         NaN                          NaN
# 7                        4.0         NaN                          NaN
# 8                        NaN         NaN                          NaN
# 9                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# 0                                        NaN                           NaN
# 1                                        3.0                           4.0
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# 5                                        NaN                           4.0
# 6                                        NaN                           5.0
# 7                                        5.0                           5.0
# 8                                        NaN                           NaN
# 9                                        NaN                           NaN
#
# title    3 Ninjas: High Noon At Mega Mountain (1998)  39 Steps, The (1935)  \
# user_id
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                1.0                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
# 5                                                NaN                   NaN
# 6                                                NaN                   NaN
# 7                                                NaN                   4.0
# 8                                                NaN                   NaN
# 9                                                NaN                   4.0
#
# title    ...  Yankee Zulu (1994)  Year of the Horse (1997)  \
# user_id  ...
# 0        ...                 NaN                       NaN
# 1        ...                 NaN                       NaN
# 2        ...                 NaN                       NaN
# 3        ...                 NaN                       NaN
# 4        ...                 NaN                       NaN
# 5        ...                 NaN                       NaN
# 6        ...                 NaN                       NaN
# 7        ...                 NaN                       NaN
# 8        ...                 NaN                       NaN
# 9        ...                 NaN                       NaN
#
# title    You So Crazy (1994)  Young Frankenstein (1974)  Young Guns (1988)  \
# user_id
# 0                        NaN                        NaN                NaN
# 1                        NaN                        5.0                3.0
# 2                        NaN                        NaN                NaN
# 3                        NaN                        NaN                NaN
# 4                        NaN                        NaN                NaN
# 5                        NaN                        4.0                NaN
# 6                        NaN                        4.0                NaN
# 7                        NaN                        5.0                3.0
# 8                        NaN                        NaN                NaN
# 9                        NaN                        NaN                NaN
#
# title    Young Guns II (1990)  Young Poisoner's Handbook, The (1995)  \
# user_id
# 0                         NaN                                    NaN
# 1                         NaN                                    NaN
# 2                         NaN                                    NaN
# 3                         NaN                                    NaN
# 4                         NaN                                    NaN
# 5                         NaN                                    NaN
# 6                         NaN                                    NaN
# 7                         NaN                                    3.0
# 8                         NaN                                    NaN
# 9                         NaN                                    NaN
#
# title    Zeus and Roxanne (1997)  unknown  Á köldum klaka (Cold Fever) (1994)
# user_id
# 0                            NaN      NaN                                 NaN
# 1                            NaN      4.0                                 NaN
# 2                            NaN      NaN                                 NaN
# 3                            NaN      NaN                                 NaN
# 4                            NaN      NaN                                 NaN
# 5                            NaN      4.0                                 NaN
# 6                            NaN      NaN                                 NaN
# 7                            NaN      NaN                                 NaN
# 8                            NaN      NaN                                 NaN
# 9                            NaN      NaN                                 NaN
#
# [10 rows x 1664 columns]

# %%
# Let's pick one movie and find similar movie recommendations

TS_rating = movie_matrix['Toy Story (1995)']
TS_rating.head()
# Out:
# user_id
# 0    NaN
# 1    5.0
# 2    4.0
# 3    NaN
# 4    NaN
# Name: Toy Story (1995), dtype: float64

# %%
# correlate Toy Story with other movies
similar_movies = movie_matrix.corrwith(TS_rating)
similar_movies = similar_movies.dropna()
similar_movies.head()
# Out:
# title
# 'Til There Was You (1997)      0.534522
# 101 Dalmatians (1996)          0.232118
# 12 Angry Men (1957)            0.334943
# 187 (1997)                     0.651857
# 2 Days in the Valley (1996)    0.162728
# dtype: float64

# %%
similar_movies.sort_values(ascending=False)
# Out:
# title
# Ladybird Ladybird (1994)                                                             1.0
# Albino Alligator (1996)                                                              1.0
# Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991)    1.0
# Critical Care (1997)                                                                 1.0
# Late Bloomers (1996)                                                                 1.0
#                                                                                     ...
# Feast of July (1995)                                                                -1.0
# Love and Death on Long Island (1997)                                                -1.0
# Slingshot, The (1993)                                                               -1.0
# Stalker (1979)                                                                      -1.0
# Heavy (1995)                                                                        -1.0
# Length: 1370, dtype: float64

# %%
similar_df = pd.DataFrame(similar_movies)
similar_df.head(10)
# Out:
#                                             0
# title
# 'Til There Was You (1997)            0.534522
# 101 Dalmatians (1996)                0.232118
# 12 Angry Men (1957)                  0.334943
# 187 (1997)                           0.651857
# 2 Days in the Valley (1996)          0.162728
# 20,000 Leagues Under the Sea (1954)  0.328472
# 2001: A Space Odyssey (1968)        -0.069060
# 39 Steps, The (1935)                 0.150055
# 8 1/2 (1963)                        -0.117259
# 8 Heads in a Duffel Bag (1997)       0.500000

# %%
similar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1370 entries, 'Til There Was You (1997) to unknown
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1370 non-null   float64
# dtypes: float64(1)
# memory usage: 61.4+ KB

# %%
import numpy as np
movieStats = movies_ratings.groupby('title').agg({'rating': [np.size, np.mean]})
movieStats.head()
# Out:
#                           rating
#                             size      mean
# title
# 'Til There Was You (1997)      9  2.333333
# 1-900 (1994)                   5  2.600000
# 101 Dalmatians (1996)        109  2.908257
# 12 Angry Men (1957)          125  4.344000
# 187 (1997)                    41  3.024390

# %%
popularMovies = movieStats['rating']['size'] >= 75
movieStats[popularMovies].sort_values([('rating', 'mean')], ascending=False)[:15]
# Out:
#                                        rating
#                                          size      mean
# title
# Close Shave, A (1995)                     112  4.491071
# Schindler's List (1993)                   298  4.466443
# Wrong Trousers, The (1993)                118  4.466102
# Casablanca (1942)                         243  4.456790
# Shawshank Redemption, The (1994)          283  4.445230
# Rear Window (1954)                        209  4.387560
# Usual Suspects, The (1995)                267  4.385768
# Star Wars (1977)                          584  4.359589
# 12 Angry Men (1957)                       125  4.344000
# Citizen Kane (1941)                       198  4.292929
# To Kill a Mockingbird (1962)              219  4.292237
# One Flew Over the Cuckoo's Nest (1975)    264  4.291667
# Silence of the Lambs, The (1991)          390  4.289744
# North by Northwest (1959)                 179  4.284916
# Godfather, The (1972)                     413  4.283293

# %%
df = movieStats[popularMovies].join(pd.DataFrame(similar_movies, columns=['similarity']))
df.head()
# Out:
# /Users/eberta/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py:643: UserWarning: merging between different levels can give an unintended result (2 levels on the left,1 on the right)
#   warnings.warn(msg, UserWarning)
#                               (rating, size)  (rating, mean)  similarity
# title
# 101 Dalmatians (1996)                    109        2.908257    0.232118
# 12 Angry Men (1957)                      125        4.344000    0.334943
# 2 Days in the Valley (1996)               93        3.225806    0.162728
# 2001: A Space Odyssey (1968)             259        3.969112   -0.069060
# Absolute Power (1997)                    127        3.370079    0.318580

# %%
df.sort_values(['similarity'], ascending=False)
# Out:
#                                              (rating, size)  (rating, mean)  \
# title
# Toy Story (1995)                                        452        3.878319
# Jackal, The (1997)                                       87        3.149425
# Craft, The (1996)                                       104        3.115385
# Beautician and the Beast, The (1997)                     86        2.313953
# Winnie the Pooh and the Blustery Day (1968)              75        3.800000
# ...                                                     ...             ...
# Wings of the Dove, The (1997)                            75        3.680000
# Apt Pupil (1998)                                        160        4.100000
# Manhattan (1979)                                         91        3.769231
# Three Colors: Red (1994)                                 83        4.060241
# Harold and Maude (1971)                                 121        3.818182
#
#                                              similarity
# title
# Toy Story (1995)                               1.000000
# Jackal, The (1997)                             0.557876
# Craft, The (1996)                              0.549100
# Beautician and the Beast, The (1997)           0.466064
# Winnie the Pooh and the Blustery Day (1968)    0.463056
# ...                                                 ...
# Wings of the Dove, The (1997)                 -0.091099
# Apt Pupil (1998)                              -0.104066
# Manhattan (1979)                              -0.106251
# Three Colors: Red (1994)                      -0.156085
# Harold and Maude (1971)                       -0.181697
#
# [440 rows x 3 columns]
